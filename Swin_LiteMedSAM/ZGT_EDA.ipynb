# %%
from pathlib import Path
import numpy as np
import pandas as pd

# %%
csv_path="/mnt/data/spathak/CLaM-Annot-metadata.csv"

df=pd.read_csv(csv_path, delimiter=";")

df['ImageID'][0]
# Out:
# '1.2.826.0.1.3680043.2.526.11.40.1608721769240233.24939309.435922'

# %%
df['AbnormalityType']=df['AbnormalityType'].fillna("None")
df['ROIPath']=df['ROIPath'].fillna("None")

df['AbnormalityType'].value_counts()
# Out:
# AbnormalityType
# Calcification               176
# Mass                        159
# None                        148
# Asymmetry                    10
# Architectural Distortion      1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['PatientID', 'StudyDate', 'CaseID', 'ViewID', 'ImageID', 'View',
#        'ROINum', 'BreastDensity', 'MammographicConspicuity', 'AbnormalityType',
#        'MassShape', 'MassMargin', 'MassDensity', 'CalcificationMorphology',
#        'CalcificationDistribution', 'AsymmetryType', 'BIRADS',
#        'MammographyDiagnosis', 'ConfidenceScore', 'PathologyDiagnosis',
#        'PatientGroundtruth', 'ImageHeight', 'ImageWidth', 'ImagePath',
#        'ROIPath'],
#       dtype='object')

# %%
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)
df
# Out:
#      PatientID  StudyDate  \
# 0            1   20180619
# 1            1   20180619
# 2            1   20180619
# 3            1   20180619
# 4            2   20180517
# ..         ...        ...
# 489         99   20180412
# 490        100   20180718
# 491        100   20180718
# 492        100   20180718
# 493        100   20180718
#
#                                                                CaseID  \
# 0    1.2.826.0.1.3680043.2.526.11.40.1608721769240233.24529438.829540
# 1    1.2.826.0.1.3680043.2.526.11.40.1608721769240233.24529438.829540
# 2    1.2.826.0.1.3680043.2.526.11.40.1608721769240233.24529438.829540
# 3    1.2.826.0.1.3680043.2.526.11.40.1608721769240233.24529438.829540
# 4    1.2.826.0.1.3680043.2.526.11.40.1608721769240233.23398232.552346
# ..                                                                ...
# 489  1.2.826.0.1.3680043.2.526.11.40.1608721769240233.20823936.661542
# 490  1.2.826.0.1.3680043.2.526.11.40.1608721769240233.25781440.377996
# ...

# %%
count = ((df["AbnormalityType"] =="Mass") & (df["MammographicConspicuity"] == "Clearly visible")).sum()
count_2=((df["AbnormalityType"] =="Mass") & (df["MammographyDiagnosis"] == "Benign")).sum()
count_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 count = ((df["AbnormalityType"] =="Mass") & (df["MammographicConspicuity"] == "Clearly visible")).sum()
#       2 count_2=((df["AbnormalityType"] =="Mass") & (df["MammographyDiagnosis"] == "Benign")).sum()
#       3 count_2
#
# NameError: name 'df' is not defined
