# %% [markdown]
# seg&det_split

# %%
import os
import pandas as pd
import numpy as np
from skimage.draw import polygon
import cv2
import pydicom as pdcm
import math
import xml.etree.ElementTree as ET
from scipy.ndimage import label

class Annotation:
    def __init__(self, xml_path, filename, shape):
        self.xml_path = xml_path + filename + '.xml'
        
        self.filename = filename
        self.shape = shape
        self.mask_mass = self.create_mask_array(shape)
        self.fill_mask()

    def fill_mask(self):
        if os.path.exists(self.xml_path):
            rois, num_rois = self.parse_XML(self.xml_path)

            for roi in rois:
                roi_info = self.get_roi_info(roi)
                r_poly, c_poly = self.create_polygon_lists(self.mask_mass, roi_info["points"])
                rr, cc = polygon(r_poly, c_poly)
                try:
                    if roi_info["roi_type"] == "Mass":
                        self.mask_mass[rr, cc] = 1  # Mass mask
                except IndexError:
                    valid_idx = (rr >= 0) & (rr < self.mask_mass.shape[0]) & (cc >= 0) & (cc < self.mask_mass.shape[1])
                    rr = rr[valid_idx]
                    cc = cc[valid_idx]
                    if roi_info["roi_type"] == "Mass":
                        self.mask_mass[rr, cc] = 1
                    print('out of bound:', self.xml_path)
                    
        else:
            print(f"not an xml path: {self.xml_path}")

    def parse_XML(self, xml_path):
        tree = ET.parse(xml_path)
        root = tree.getroot()  # The root of the XML file
        data = root[0][1]  # The essential info
        rois = data[0][5]  # Array containing the ROI objects
        num_of_rois = int(data[0][3].text)  # Number of ROI objects
        return rois, num_of_rois

    def create_mask_array(self, img_shape):
        return np.zeros((img_shape[0], img_shape[1]), dtype=np.uint8)

    def get_roi_info(self, roi):
        roi_info = {
            "points": roi[21],  # Array containing the points of a ROI
            "num_of_points": int(roi[17].text),  # Number of points of the area
            "roi_index": int(roi[7].text),  # Identifier of the ROI
            "roi_type": roi[15].text  # (Mass, Calcification, other)
        }
        print(roi_info)
        return roi_info

    def create_polygon_lists(self, mask, points):
        r_poly = np.array([])
        c_poly = np.array([])

        for point in points:
            temp_tuple = point.text[1:-1].split(",")
            y = int(math.trunc(float(temp_tuple[0])))
            x = int(math.trunc(float(temp_tuple[1])))
            r_poly = np.append(r_poly, x)
            c_poly = np.append(c_poly, y)

        return r_poly, c_poly

    def bboxes_from_mask(self, mask):
        labeled, num = label(mask > 0)
        boxes = []

        for component_id in range(1, num + 1):
            ys, xs = np.where(labeled == component_id)
            if len(xs) == 0:
                continue

            boxes.append([
                int(xs.min()),
                int(ys.min()),
                int(xs.max() + 1),
                int(ys.max() + 1),
            ])

        return boxes

    def np_CountUpContinuingOnes(self, b_arr):
        left = np.arange(len(b_arr))
        left[b_arr > 0] = 0
        left = np.maximum.accumulate(left)

        rev_arr = b_arr[::-1]
        right = np.arange(len(rev_arr))
        right[rev_arr > 0] = 0
        right = np.maximum.accumulate(right)
        right = len(rev_arr) - 1 - right[::-1]

        return right - left - 1

    def adjust_bounding_box(self, original_coords, left_crop, top_crop):
        x1, y1, x2, y2 = original_coords
        x1_new = x1 - left_crop
        y1_new = y1 - top_crop
        x2_new = x2 - left_crop
        y2_new = y2 - top_crop
        return x1_new, y1_new, x2_new, y2_new

    def ExtractBreast(self, img, mask, true_bounding_boxes):
        img_copy = img.copy()
        mask_copy = mask.copy()
        img = np.where(img <= 20, 0, img)
        height, _ = img.shape

        y_a = height // 2 + int(height * 0.4)
        y_b = height // 2 - int(height * 0.4)
        b_arr = img[y_b:y_a].std(axis=0) != 0
        continuing_ones = self.np_CountUpContinuingOnes(b_arr)
        col_ind = np.where(continuing_ones == continuing_ones.max())[0]
        img = img[:, col_ind]
        mask = mask[:, col_ind]

        _, width = img.shape
        x_a = width // 2 + int(width * 0.4)
        x_b = width // 2 - int(width * 0.4)
        b_arr = img[:, x_b:x_a].std(axis=1) != 0
        continuing_ones = self.np_CountUpContinuingOnes(b_arr)
        row_ind = np.where(continuing_ones == continuing_ones.max())[0]
        img = img[row_ind, :]
        mask = mask[row_ind, :]

        adjusted_bboxes = []
        for bbox in true_bounding_boxes:
            adjusted_coords = self.adjust_bounding_box(bbox, col_ind[0], row_ind[0])
            adjusted_bboxes.append(adjusted_coords)

        return img_copy[row_ind][:, col_ind], mask_copy[row_ind][:, col_ind], adjusted_bboxes
    

    def save_data(self, img, mask, bboxes, output_dir, img_name):
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        jpg_path = os.path.join(output_dir, f'img.jpg')
        cv2.imwrite(jpg_path, img)

        png_path = os.path.join(output_dir, f'mask.png')
        cv2.imwrite(png_path, mask * 255)

        npy_path = os.path.join(output_dir, f'bboxes.npy')
        np.save(npy_path, np.array(bboxes))

        print(f'Data saved for {img_name} in {output_dir}')

    def save_mask_and_image(self, dcm_path, output_base_path, img_name, data_split):
        dcm = pdcm.dcmread(dcm_path)
        img = dcm.pixel_array
        processed_img, processed_mask, _ = self.ExtractBreast(img, self.mask_mass, [])
        processed_bboxes = self.bboxes_from_mask(processed_mask)
        img = cv2.normalize(processed_img, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
        
        if np.any(self.mask_mass == 1):
            output_dir = os.path.join(output_base_path, data_split, img_name)
            self.save_data(img, self.mask_mass, processed_bboxes, output_dir, img_name)
        else:
            print("self.mask_mass != 1")

split_csv_path = "../segdetdata/segdet_split.csv"
split_df = pd.read_csv(split_csv_path)
split_df = split_df[split_df['dataset'] == 'INbreast']


XML_PATH = "/home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/AllXML/"
DCM_PATH = "/home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/AllDICOMs"
OUTPUT_BASE_PATH = "/home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format"

dicom_files = [f for f in os.listdir(DCM_PATH) if f.endswith('.dcm') and not f.startswith('._')]
processed_count = 0

for filename in dicom_files:
    img_name = filename.split('.')[0]
    img_name=img_name.split('_')[0]
    
    split_info = split_df[split_df['data_name'] == img_name]
    if split_info.empty:
        print(f"No split info found for {img_name}")
        continue
    
    data_split = split_info['data_split'].values[0]
    dcm_path = os.path.join(DCM_PATH, filename)
    
    try:
        dcm = pdcm.dcmread(dcm_path)
        img = dcm.pixel_array
        annotation = Annotation(XML_PATH, img_name, img.shape)
        annotation.save_mask_and_image(dcm_path, OUTPUT_BASE_PATH, img_name, data_split)
        processed_count += 1
    except Exception as e:
        print(f"Error processing {img_name}: {str(e)}")

print(f"Dataset processing completed. Total processed: {processed_count}")
# Out:
# {'points': <Element 'array' at 0x7f9c9435af20>, 'num_of_points': 1, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435a520>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94359b20>, 'num_of_points': 1, 'roi_index': 2, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94358ef0>, 'num_of_points': 1, 'roi_index': 3, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433fce0>, 'num_of_points': 9, 'roi_index': 4, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433eca0>, 'num_of_points': 1, 'roi_index': 5, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433e1b0>, 'num_of_points': 1, 'roi_index': 6, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433d760>, 'num_of_points': 1, 'roi_index': 7, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433c900>, 'num_of_points': 1, 'roi_index': 8, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c944adcb0>, 'num_of_points': 1, 'roi_index': 9, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c944af6f0>, 'num_of_points': 1, 'roi_index': 10, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437d4e0>, 'num_of_points': 1, 'roi_index': 11, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437c1d0>, 'num_of_points': 14, 'roi_index': 12, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437ee30>, 'num_of_points': 1, 'roi_index': 13, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437fc40>, 'num_of_points': 6, 'roi_index': 14, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9438c9a0>, 'num_of_points': 1, 'roi_index': 15, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9438d3a0>, 'num_of_points': 1, 'roi_index': 16, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9438eed0>, 'num_of_points': 27, 'roi_index': 17, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c94384950>, 'num_of_points': 1, 'roi_index': 18, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94385350>, 'num_of_points': 1, 'roi_index': 19, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94385d50>, 'num_of_points': 1, 'roi_index': 20, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94386750>, 'num_of_points': 1, 'roi_index': 21, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94387150>, 'num_of_points': 1, 'roi_index': 22, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94387b50>, 'num_of_points': 1, 'roi_index': 23, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436f010>, 'num_of_points': 16, 'roi_index': 24, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436dcb0>, 'num_of_points': 1, 'roi_index': 25, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436d2b0>, 'num_of_points': 1, 'roi_index': 26, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436c220>, 'num_of_points': 10, 'roi_index': 27, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94398db0>, 'num_of_points': 1, 'roi_index': 28, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943997b0>, 'num_of_points': 1, 'roi_index': 29, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439a1b0>, 'num_of_points': 1, 'roi_index': 30, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439abb0>, 'num_of_points': 1, 'roi_index': 31, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439b5b0>, 'num_of_points': 1, 'roi_index': 32, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439bfb0>, 'num_of_points': 1, 'roi_index': 33, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943a49f0>, 'num_of_points': 1, 'roi_index': 34, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943a5760>, 'num_of_points': 5, 'roi_index': 35, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b1c10>, 'num_of_points': 89, 'roi_index': 36, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c943b5d50>, 'num_of_points': 1, 'roi_index': 37, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b74c0>, 'num_of_points': 21, 'roi_index': 38, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c4f90>, 'num_of_points': 6, 'roi_index': 39, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c5f30>, 'num_of_points': 4, 'roi_index': 40, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c6b10>, 'num_of_points': 1, 'roi_index': 41, 'roi_type': 'Calcification'}
# Data saved for 20586908 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Eval/20586908
# {'points': <Element 'array' at 0x7f9c9437e750>, 'num_of_points': 14, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437c810>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437dcb0>, 'num_of_points': 1, 'roi_index': 2, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c944af2e0>, 'num_of_points': 1, 'roi_index': 3, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c944af330>, 'num_of_points': 1, 'roi_index': 4, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433c540>, 'num_of_points': 1, 'roi_index': 5, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433d4e0>, 'num_of_points': 1, 'roi_index': 6, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433df80>, 'num_of_points': 1, 'roi_index': 7, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433ea20>, 'num_of_points': 1, 'roi_index': 8, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433fe70>, 'num_of_points': 13, 'roi_index': 9, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94359210>, 'num_of_points': 4, 'roi_index': 10, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435acf0>, 'num_of_points': 5, 'roi_index': 11, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435af70>, 'num_of_points': 1, 'roi_index': 12, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435ba10>, 'num_of_points': 1, 'roi_index': 13, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c6610>, 'num_of_points': 1, 'roi_index': 14, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c5cb0>, 'num_of_points': 1, 'roi_index': 15, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c52b0>, 'num_of_points': 1, 'roi_index': 16, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c4810>, 'num_of_points': 1, 'roi_index': 17, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c6fc0>, 'num_of_points': 1, 'roi_index': 18, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c79c0>, 'num_of_points': 1, 'roi_index': 19, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94370770>, 'num_of_points': 5, 'roi_index': 20, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943715d0>, 'num_of_points': 3, 'roi_index': 21, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94372110>, 'num_of_points': 1, 'roi_index': 22, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94372e30>, 'num_of_points': 5, 'roi_index': 23, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94373ab0>, 'num_of_points': 1, 'roi_index': 24, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439bd30>, 'num_of_points': 200, 'roi_index': 25, 'roi_type': 'Spiculated Region'}
# {'points': <Element 'array' at 0x7f9c94368f90>, 'num_of_points': 9, 'roi_index': 26, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436a2a0>, 'num_of_points': 6, 'roi_index': 27, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436afc0>, 'num_of_points': 1, 'roi_index': 28, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436b9c0>, 'num_of_points': 1, 'roi_index': 29, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94380400>, 'num_of_points': 1, 'roi_index': 30, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94380e00>, 'num_of_points': 1, 'roi_index': 31, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94381800>, 'num_of_points': 1, 'roi_index': 32, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943827f0>, 'num_of_points': 9, 'roi_index': 33, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94383d80>, 'num_of_points': 10, 'roi_index': 34, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9438f2e0>, 'num_of_points': 1, 'roi_index': 35, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9438df30>, 'num_of_points': 16, 'roi_index': 36, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9438c720>, 'num_of_points': 6, 'roi_index': 37, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941d0c70>, 'num_of_points': 9, 'roi_index': 38, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941d1b70>, 'num_of_points': 1, 'roi_index': 39, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941d2570>, 'num_of_points': 1, 'roi_index': 40, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941d32e0>, 'num_of_points': 5, 'roi_index': 41, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941dc450>, 'num_of_points': 7, 'roi_index': 42, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941e7ce0>, 'num_of_points': 170, 'roi_index': 43, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c941f35b0>, 'num_of_points': 7, 'roi_index': 44, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941fc3b0>, 'num_of_points': 1, 'roi_index': 45, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941fcdb0>, 'num_of_points': 1, 'roi_index': 46, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941fd7b0>, 'num_of_points': 1, 'roi_index': 47, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941fe1b0>, 'num_of_points': 1, 'roi_index': 48, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941febb0>, 'num_of_points': 1, 'roi_index': 49, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941ff5b0>, 'num_of_points': 1, 'roi_index': 50, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942082c0>, 'num_of_points': 4, 'roi_index': 51, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94208ea0>, 'num_of_points': 1, 'roi_index': 52, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9420a250>, 'num_of_points': 15, 'roi_index': 53, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9420b510>, 'num_of_points': 1, 'roi_index': 54, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9420bf10>, 'num_of_points': 1, 'roi_index': 55, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94214950>, 'num_of_points': 1, 'roi_index': 56, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94215350>, 'num_of_points': 1, 'roi_index': 57, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94215d50>, 'num_of_points': 1, 'roi_index': 58, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94216f20>, 'num_of_points': 12, 'roi_index': 59, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94220040>, 'num_of_points': 1, 'roi_index': 60, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94221710>, 'num_of_points': 20, 'roi_index': 61, 'roi_type': 'Calcification'}
# Data saved for 20586934 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/20586934
# {'points': <Element 'array' at 0x7f9c941c7010>, 'num_of_points': 1, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c47c0>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c5620>, 'num_of_points': 7, 'roi_index': 2, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c6a70>, 'num_of_points': 9, 'roi_index': 3, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435ab10>, 'num_of_points': 9, 'roi_index': 4, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94359c10>, 'num_of_points': 1, 'roi_index': 5, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94359030>, 'num_of_points': 1, 'roi_index': 6, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943582c0>, 'num_of_points': 1, 'roi_index': 7, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433fc40>, 'num_of_points': 1, 'roi_index': 8, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433f290>, 'num_of_points': 1, 'roi_index': 9, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433e700>, 'num_of_points': 1, 'roi_index': 10, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433db20>, 'num_of_points': 1, 'roi_index': 11, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433ce00>, 'num_of_points': 1, 'roi_index': 12, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9e1574cfe0>, 'num_of_points': 1, 'roi_index': 13, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c944aefc0>, 'num_of_points': 1, 'roi_index': 14, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437db20>, 'num_of_points': 1, 'roi_index': 15, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437eb60>, 'num_of_points': 50, 'roi_index': 16, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c94383330>, 'num_of_points': 87, 'roi_index': 17, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c94374d10>, 'num_of_points': 1, 'roi_index': 18, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94375710>, 'num_of_points': 1, 'roi_index': 19, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94376110>, 'num_of_points': 1, 'roi_index': 20, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94376b10>, 'num_of_points': 1, 'roi_index': 21, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943777e0>, 'num_of_points': 4, 'roi_index': 22, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436ce00>, 'num_of_points': 16, 'roi_index': 23, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436e160>, 'num_of_points': 1, 'roi_index': 24, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436f790>, 'num_of_points': 19, 'roi_index': 25, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94399530>, 'num_of_points': 13, 'roi_index': 26, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439a3e0>, 'num_of_points': 10, 'roi_index': 27, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439bd80>, 'num_of_points': 1, 'roi_index': 28, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439c770>, 'num_of_points': 1, 'roi_index': 29, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439d170>, 'num_of_points': 1, 'roi_index': 30, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439db70>, 'num_of_points': 1, 'roi_index': 31, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439e570>, 'num_of_points': 1, 'roi_index': 32, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439ef70>, 'num_of_points': 1, 'roi_index': 33, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439f970>, 'num_of_points': 1, 'roi_index': 34, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b83b0>, 'num_of_points': 1, 'roi_index': 35, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b8db0>, 'num_of_points': 1, 'roi_index': 36, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b97b0>, 'num_of_points': 1, 'roi_index': 37, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943ba1b0>, 'num_of_points': 1, 'roi_index': 38, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943babb0>, 'num_of_points': 1, 'roi_index': 39, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943bb5b0>, 'num_of_points': 1, 'roi_index': 40, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942109f0>, 'num_of_points': 16, 'roi_index': 41, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94212110>, 'num_of_points': 6, 'roi_index': 42, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94212e30>, 'num_of_points': 1, 'roi_index': 43, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94213830>, 'num_of_points': 1, 'roi_index': 44, 'roi_type': 'Calcification'}
# Data saved for 20586960 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/20586960
# {'points': <Element 'array' at 0x7f9c9437ec50>, 'num_of_points': 1, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437e2f0>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437c450>, 'num_of_points': 1, 'roi_index': 2, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437cef0>, 'num_of_points': 1, 'roi_index': 3, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435b290>, 'num_of_points': 200, 'roi_index': 4, 'roi_type': 'Spiculated Region'}
# {'points': <Element 'array' at 0x7f9c943a7c90>, 'num_of_points': 1, 'roi_index': 5, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943bb9c0>, 'num_of_points': 1, 'roi_index': 6, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943baf20>, 'num_of_points': 1, 'roi_index': 7, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943ba520>, 'num_of_points': 1, 'roi_index': 8, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b9b20>, 'num_of_points': 1, 'roi_index': 9, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b9120>, 'num_of_points': 1, 'roi_index': 10, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b8720>, 'num_of_points': 1, 'roi_index': 11, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94378310>, 'num_of_points': 1, 'roi_index': 12, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94378d10>, 'num_of_points': 1, 'roi_index': 13, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439b740>, 'num_of_points': 284, 'roi_index': 14, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c94377b00>, 'num_of_points': 1, 'roi_index': 15, 'roi_type': 'Calcification'}
# Data saved for 20586986 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/20586986
# No split info found for 20587054
# No split info found for 20587080
# No split info found for 20587148
# No split info found for 20587174
# No split info found for 20587200
# No split info found for 20587226
# No split info found for 20587294
# No split info found for 20587320
# No split info found for 20587346
# No split info found for 20587372
# No split info found for 20587466
# No split info found for 20587492
# No split info found for 20587518
# No split info found for 20587544
# {'points': <Element 'array' at 0x7f9c941c4090>, 'num_of_points': 1, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c4c70>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c5120>, 'num_of_points': 1, 'roi_index': 2, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c5f80>, 'num_of_points': 1, 'roi_index': 3, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c69d0>, 'num_of_points': 1, 'roi_index': 4, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435bb00>, 'num_of_points': 1, 'roi_index': 5, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435b060>, 'num_of_points': 1, 'roi_index': 6, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435a660>, 'num_of_points': 1, 'roi_index': 7, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94359c60>, 'num_of_points': 1, 'roi_index': 8, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943590d0>, 'num_of_points': 1, 'roi_index': 9, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943583b0>, 'num_of_points': 1, 'roi_index': 10, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433fdd0>, 'num_of_points': 1, 'roi_index': 11, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433f1a0>, 'num_of_points': 1, 'roi_index': 12, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433e660>, 'num_of_points': 1, 'roi_index': 13, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433dad0>, 'num_of_points': 1, 'roi_index': 14, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433cd10>, 'num_of_points': 1, 'roi_index': 15, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942e1670>, 'num_of_points': 1, 'roi_index': 16, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c944aef20>, 'num_of_points': 1, 'roi_index': 17, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437d080>, 'num_of_points': 1, 'roi_index': 18, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437d530>, 'num_of_points': 1, 'roi_index': 19, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437ca40>, 'num_of_points': 1, 'roi_index': 20, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437c040>, 'num_of_points': 1, 'roi_index': 21, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437e7f0>, 'num_of_points': 1, 'roi_index': 22, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437f1a0>, 'num_of_points': 1, 'roi_index': 23, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b4040>, 'num_of_points': 1, 'roi_index': 24, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b4a40>, 'num_of_points': 1, 'roi_index': 25, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b5440>, 'num_of_points': 1, 'roi_index': 26, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b5e40>, 'num_of_points': 1, 'roi_index': 27, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b6840>, 'num_of_points': 1, 'roi_index': 28, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b7240>, 'num_of_points': 1, 'roi_index': 29, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b7c40>, 'num_of_points': 1, 'roi_index': 30, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943986d0>, 'num_of_points': 1, 'roi_index': 31, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94399170>, 'num_of_points': 1, 'roi_index': 32, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94399b70>, 'num_of_points': 1, 'roi_index': 33, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439a570>, 'num_of_points': 1, 'roi_index': 34, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439afc0>, 'num_of_points': 1, 'roi_index': 35, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439b830>, 'num_of_points': 1, 'roi_index': 36, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b3d80>, 'num_of_points': 1, 'roi_index': 37, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b3380>, 'num_of_points': 1, 'roi_index': 38, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b2980>, 'num_of_points': 1, 'roi_index': 39, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b1f80>, 'num_of_points': 1, 'roi_index': 40, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b1580>, 'num_of_points': 1, 'roi_index': 41, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b02c0>, 'num_of_points': 14, 'roi_index': 42, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b9530>, 'num_of_points': 8, 'roi_index': 43, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943ba390>, 'num_of_points': 1, 'roi_index': 44, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943bad90>, 'num_of_points': 1, 'roi_index': 45, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943bade0>, 'num_of_points': 1, 'roi_index': 46, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943681d0>, 'num_of_points': 1, 'roi_index': 47, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94368bd0>, 'num_of_points': 1, 'roi_index': 48, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943695d0>, 'num_of_points': 1, 'roi_index': 49, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94369fd0>, 'num_of_points': 1, 'roi_index': 50, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436a9d0>, 'num_of_points': 1, 'roi_index': 51, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436b3d0>, 'num_of_points': 1, 'roi_index': 52, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436bdd0>, 'num_of_points': 1, 'roi_index': 53, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94214810>, 'num_of_points': 1, 'roi_index': 54, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94215210>, 'num_of_points': 1, 'roi_index': 55, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94215c10>, 'num_of_points': 1, 'roi_index': 56, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94216610>, 'num_of_points': 1, 'roi_index': 57, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94217010>, 'num_of_points': 1, 'roi_index': 58, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94217a10>, 'num_of_points': 1, 'roi_index': 59, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94220450>, 'num_of_points': 1, 'roi_index': 60, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94220e50>, 'num_of_points': 1, 'roi_index': 61, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94221850>, 'num_of_points': 1, 'roi_index': 62, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94222250>, 'num_of_points': 1, 'roi_index': 63, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94222c50>, 'num_of_points': 1, 'roi_index': 64, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94223650>, 'num_of_points': 1, 'roi_index': 65, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94208090>, 'num_of_points': 1, 'roi_index': 66, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94208a90>, 'num_of_points': 1, 'roi_index': 67, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94209490>, 'num_of_points': 1, 'roi_index': 68, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94209e90>, 'num_of_points': 1, 'roi_index': 69, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9420a890>, 'num_of_points': 1, 'roi_index': 70, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9420b290>, 'num_of_points': 1, 'roi_index': 71, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9420bc90>, 'num_of_points': 1, 'roi_index': 72, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941fc6d0>, 'num_of_points': 1, 'roi_index': 73, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941fd0d0>, 'num_of_points': 1, 'roi_index': 74, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941fdad0>, 'num_of_points': 1, 'roi_index': 75, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941fe4d0>, 'num_of_points': 1, 'roi_index': 76, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941feed0>, 'num_of_points': 1, 'roi_index': 77, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941ff8d0>, 'num_of_points': 1, 'roi_index': 78, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941f4310>, 'num_of_points': 1, 'roi_index': 79, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941f4d10>, 'num_of_points': 1, 'roi_index': 80, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941f5710>, 'num_of_points': 1, 'roi_index': 81, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941f6110>, 'num_of_points': 1, 'roi_index': 82, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941f6b10>, 'num_of_points': 1, 'roi_index': 83, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941f7510>, 'num_of_points': 1, 'roi_index': 84, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941f7f10>, 'num_of_points': 1, 'roi_index': 85, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941ec950>, 'num_of_points': 1, 'roi_index': 86, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941ed350>, 'num_of_points': 1, 'roi_index': 87, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941edd50>, 'num_of_points': 1, 'roi_index': 88, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941ee750>, 'num_of_points': 1, 'roi_index': 89, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c2f70>, 'num_of_points': 200, 'roi_index': 90, 'roi_type': 'Spiculated Region'}
# {'points': <Element 'array' at 0x7f9c9423dd50>, 'num_of_points': 164, 'roi_index': 91, 'roi_type': 'Mass'}
# Data saved for 20587612 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Test/20587612
# No split info found for 20587638
# {'points': <Element 'array' at 0x7f9c9437f5b0>, 'num_of_points': 1, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437d260>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437e160>, 'num_of_points': 1, 'roi_index': 2, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437c680>, 'num_of_points': 1, 'roi_index': 3, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437db20>, 'num_of_points': 1, 'roi_index': 4, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c944aec00>, 'num_of_points': 1, 'roi_index': 5, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c944af830>, 'num_of_points': 1, 'roi_index': 6, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433c8b0>, 'num_of_points': 1, 'roi_index': 7, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433d800>, 'num_of_points': 1, 'roi_index': 8, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433e2a0>, 'num_of_points': 1, 'roi_index': 9, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433ed90>, 'num_of_points': 1, 'roi_index': 10, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433f920>, 'num_of_points': 1, 'roi_index': 11, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94358c70>, 'num_of_points': 1, 'roi_index': 12, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94358ae0>, 'num_of_points': 1, 'roi_index': 13, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94359800>, 'num_of_points': 1, 'roi_index': 14, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435a200>, 'num_of_points': 1, 'roi_index': 15, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435ac00>, 'num_of_points': 1, 'roi_index': 16, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435b970>, 'num_of_points': 1, 'roi_index': 17, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c7ec0>, 'num_of_points': 1, 'roi_index': 18, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c65c0>, 'num_of_points': 1, 'roi_index': 19, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c5cb0>, 'num_of_points': 1, 'roi_index': 20, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c52b0>, 'num_of_points': 1, 'roi_index': 21, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c4810>, 'num_of_points': 1, 'roi_index': 22, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c6fc0>, 'num_of_points': 1, 'roi_index': 23, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94380040>, 'num_of_points': 1, 'roi_index': 24, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94380a40>, 'num_of_points': 1, 'roi_index': 25, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94381440>, 'num_of_points': 1, 'roi_index': 26, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94381e40>, 'num_of_points': 1, 'roi_index': 27, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94382840>, 'num_of_points': 1, 'roi_index': 28, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94383240>, 'num_of_points': 1, 'roi_index': 29, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94383c40>, 'num_of_points': 1, 'roi_index': 30, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9438c680>, 'num_of_points': 1, 'roi_index': 31, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9438d080>, 'num_of_points': 1, 'roi_index': 32, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9438da80>, 'num_of_points': 1, 'roi_index': 33, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9438e480>, 'num_of_points': 1, 'roi_index': 34, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9438ee80>, 'num_of_points': 1, 'roi_index': 35, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9438f880>, 'num_of_points': 1, 'roi_index': 36, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943a42c0>, 'num_of_points': 1, 'roi_index': 37, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943a4cc0>, 'num_of_points': 1, 'roi_index': 38, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943a56c0>, 'num_of_points': 1, 'roi_index': 39, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943a60c0>, 'num_of_points': 1, 'roi_index': 40, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943a6ac0>, 'num_of_points': 1, 'roi_index': 41, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943a74c0>, 'num_of_points': 1, 'roi_index': 42, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943a7ec0>, 'num_of_points': 1, 'roi_index': 43, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439c900>, 'num_of_points': 1, 'roi_index': 44, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439d300>, 'num_of_points': 1, 'roi_index': 45, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439dd00>, 'num_of_points': 1, 'roi_index': 46, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439e700>, 'num_of_points': 1, 'roi_index': 47, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439f100>, 'num_of_points': 1, 'roi_index': 48, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439fb00>, 'num_of_points': 1, 'roi_index': 49, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94370540>, 'num_of_points': 1, 'roi_index': 50, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94370f40>, 'num_of_points': 1, 'roi_index': 51, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94371940>, 'num_of_points': 1, 'roi_index': 52, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94372340>, 'num_of_points': 1, 'roi_index': 53, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94372d40>, 'num_of_points': 1, 'roi_index': 54, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94373740>, 'num_of_points': 1, 'roi_index': 55, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94230180>, 'num_of_points': 1, 'roi_index': 56, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94230b80>, 'num_of_points': 1, 'roi_index': 57, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94231580>, 'num_of_points': 1, 'roi_index': 58, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94231f80>, 'num_of_points': 1, 'roi_index': 59, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94232980>, 'num_of_points': 1, 'roi_index': 60, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94233380>, 'num_of_points': 1, 'roi_index': 61, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94233d80>, 'num_of_points': 1, 'roi_index': 62, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942407c0>, 'num_of_points': 1, 'roi_index': 63, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942411c0>, 'num_of_points': 1, 'roi_index': 64, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94241bc0>, 'num_of_points': 1, 'roi_index': 65, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942425c0>, 'num_of_points': 1, 'roi_index': 66, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94242fc0>, 'num_of_points': 1, 'roi_index': 67, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942439c0>, 'num_of_points': 1, 'roi_index': 68, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9422fc40>, 'num_of_points': 1, 'roi_index': 69, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9422f240>, 'num_of_points': 1, 'roi_index': 70, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9422e7a0>, 'num_of_points': 1, 'roi_index': 71, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9422dda0>, 'num_of_points': 1, 'roi_index': 72, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9422d3a0>, 'num_of_points': 1, 'roi_index': 73, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9422c9a0>, 'num_of_points': 1, 'roi_index': 74, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941ee980>, 'num_of_points': 1, 'roi_index': 75, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941ef600>, 'num_of_points': 1, 'roi_index': 76, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94229260>, 'num_of_points': 200, 'roi_index': 77, 'roi_type': 'Spiculated Region'}
# {'points': <Element 'array' at 0x7f9c9425a610>, 'num_of_points': 122, 'roi_index': 78, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c941f3bf0>, 'num_of_points': 1, 'roi_index': 79, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94200630>, 'num_of_points': 1, 'roi_index': 80, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94201c60>, 'num_of_points': 19, 'roi_index': 81, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94203150>, 'num_of_points': 1, 'roi_index': 82, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94203ba0>, 'num_of_points': 1, 'roi_index': 83, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941cc5e0>, 'num_of_points': 1, 'roi_index': 84, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941ccfe0>, 'num_of_points': 1, 'roi_index': 85, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941cd9e0>, 'num_of_points': 1, 'roi_index': 86, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941ce3e0>, 'num_of_points': 1, 'roi_index': 87, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941cede0>, 'num_of_points': 1, 'roi_index': 88, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941cf7e0>, 'num_of_points': 1, 'roi_index': 89, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9425c220>, 'num_of_points': 1, 'roi_index': 90, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9425cc20>, 'num_of_points': 1, 'roi_index': 91, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9425d620>, 'num_of_points': 1, 'roi_index': 92, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9425e020>, 'num_of_points': 1, 'roi_index': 93, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9425ea20>, 'num_of_points': 1, 'roi_index': 94, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9425f420>, 'num_of_points': 1, 'roi_index': 95, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9425fe20>, 'num_of_points': 1, 'roi_index': 96, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94260860>, 'num_of_points': 1, 'roi_index': 97, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94261260>, 'num_of_points': 1, 'roi_index': 98, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94261c60>, 'num_of_points': 1, 'roi_index': 99, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94262660>, 'num_of_points': 1, 'roi_index': 100, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94263060>, 'num_of_points': 1, 'roi_index': 101, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94263a60>, 'num_of_points': 1, 'roi_index': 102, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942704a0>, 'num_of_points': 1, 'roi_index': 103, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94270ea0>, 'num_of_points': 1, 'roi_index': 104, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942718a0>, 'num_of_points': 1, 'roi_index': 105, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942722a0>, 'num_of_points': 1, 'roi_index': 106, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94272ca0>, 'num_of_points': 1, 'roi_index': 107, 'roi_type': 'Calcification'}
# Data saved for 20587664 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/20587664
# No split info found for 20587690
# {'points': <Element 'array' at 0x7f9c94359990>, 'num_of_points': 132, 'roi_index': 0, 'roi_type': 'Mass'}
# Data saved for 20587758 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/20587758
# No split info found for 20587784
# {'points': <Element 'array' at 0x7f9c943584a0>, 'num_of_points': 74, 'roi_index': 0, 'roi_type': 'Mass'}
# Data saved for 20587810 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/20587810
# No split info found for 20587836
# {'points': <Element 'array' at 0x7f9c94358c70>, 'num_of_points': 144, 'roi_index': 0, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c9437d030>, 'num_of_points': 13, 'roi_index': 1, 'roi_type': 'Calcification'}
# Data saved for 20587902 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/20587902
# {'points': <Element 'array' at 0x7f9c941c7330>, 'num_of_points': 10, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435a2f0>, 'num_of_points': 113, 'roi_index': 1, 'roi_type': 'Mass'}
# Data saved for 20587928 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/20587928
# {'points': <Element 'array' at 0x7f9c943106d0>, 'num_of_points': 200, 'roi_index': 0, 'roi_type': 'Spiculated Region'}
# {'points': <Element 'array' at 0x7f9c94369350>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943b5300>, 'num_of_points': 187, 'roi_index': 2, 'roi_type': 'Mass'}
# Data saved for 20587994 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/20587994
# No split info found for 20588020
# {'points': <Element 'array' at 0x7f9c944af830>, 'num_of_points': 180, 'roi_index': 0, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c94397790>, 'num_of_points': 200, 'roi_index': 1, 'roi_type': 'Spiculated Region'}
# {'points': <Element 'array' at 0x7f9c9436c130>, 'num_of_points': 1, 'roi_index': 2, 'roi_type': 'Calcification'}
# Data saved for 20588046 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/20588046
# No split info found for 20588072
# No split info found for 20588138
# No split info found for 20588164
# {'points': <Element 'array' at 0x7f9c94358db0>, 'num_of_points': 53, 'roi_index': 0, 'roi_type': 'Mass'}
# Data saved for 20588190 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Test/20588190
# {'points': <Element 'array' at 0x7f9c941c5ad0>, 'num_of_points': 113, 'roi_index': 0, 'roi_type': 'Mass'}
# Data saved for 20588216 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/20588216
# {'points': <Element 'array' at 0x7f9c9435b970>, 'num_of_points': 115, 'roi_index': 0, 'roi_type': 'Mass'}
# Data saved for 20588308 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/20588308
# {'points': <Element 'array' at 0x7f9c941c51c0>, 'num_of_points': 135, 'roi_index': 0, 'roi_type': 'Mass'}
# Data saved for 20588334 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Test/20588334
# No split info found for 20588458
# No split info found for 20588510
# {'points': <Element 'array' at 0x7f9d3a370360>, 'num_of_points': 1, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c6e30>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c4a90>, 'num_of_points': 1, 'roi_index': 2, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c52b0>, 'num_of_points': 1, 'roi_index': 3, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c5cb0>, 'num_of_points': 1, 'roi_index': 4, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437d0d0>, 'num_of_points': 229, 'roi_index': 5, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c9436a7f0>, 'num_of_points': 1, 'roi_index': 6, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436b1f0>, 'num_of_points': 1, 'roi_index': 7, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9436bbf0>, 'num_of_points': 1, 'roi_index': 8, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94394630>, 'num_of_points': 1, 'roi_index': 9, 'roi_type': 'Calcification'}
# Data saved for 20588536 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Test/20588536
# {'points': <Element 'array' at 0x7f9c9437e520>, 'num_of_points': 1, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437c2c0>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437d940>, 'num_of_points': 1, 'roi_index': 2, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9437d3a0>, 'num_of_points': 1, 'roi_index': 3, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94359850>, 'num_of_points': 134, 'roi_index': 4, 'roi_type': 'Mass'}
# ...
# {'points': <Element 'array' at 0x7f9c94378540>, 'num_of_points': 13, 'roi_index': 18, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943ae9d0>, 'num_of_points': 16, 'roi_index': 19, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943ace00>, 'num_of_points': 14, 'roi_index': 20, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94383650>, 'num_of_points': 10, 'roi_index': 21, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943a47c0>, 'num_of_points': 73, 'roi_index': 22, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943a2390>, 'num_of_points': 48, 'roi_index': 23, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9439bb00>, 'num_of_points': 104, 'roi_index': 24, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94291210>, 'num_of_points': 106, 'roi_index': 25, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942943b0>, 'num_of_points': 49, 'roi_index': 26, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941d3ab0>, 'num_of_points': 36, 'roi_index': 27, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c14e0>, 'num_of_points': 27, 'roi_index': 28, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942645e0>, 'num_of_points': 1, 'roi_index': 29, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94264fe0>, 'num_of_points': 1, 'roi_index': 30, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94266890>, 'num_of_points': 24, 'roi_index': 31, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94277a60>, 'num_of_points': 9, 'roi_index': 32, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94275710>, 'num_of_points': 33, 'roi_index': 33, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942add00>, 'num_of_points': 34, 'roi_index': 34, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941e7920>, 'num_of_points': 19, 'roi_index': 35, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941e5f80>, 'num_of_points': 7, 'roi_index': 36, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941e4d10>, 'num_of_points': 7, 'roi_index': 37, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942289a0>, 'num_of_points': 15, 'roi_index': 38, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9422a250>, 'num_of_points': 10, 'roi_index': 39, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9422bc40>, 'num_of_points': 17, 'roi_index': 40, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9429e9d0>, 'num_of_points': 10, 'roi_index': 41, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9429d3f0>, 'num_of_points': 11, 'roi_index': 42, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94247a60>, 'num_of_points': 15, 'roi_index': 43, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941eb2e0>, 'num_of_points': 85, 'roi_index': 44, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94282d40>, 'num_of_points': 10, 'roi_index': 45, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9420dad0>, 'num_of_points': 108, 'roi_index': 46, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94222b10>, 'num_of_points': 90, 'roi_index': 47, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94217420>, 'num_of_points': 12, 'roi_index': 48, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942609f0>, 'num_of_points': 8, 'roi_index': 49, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94261850>, 'num_of_points': 1, 'roi_index': 50, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942624d0>, 'num_of_points': 5, 'roi_index': 51, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94263470>, 'num_of_points': 5, 'roi_index': 52, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9428b4c0>, 'num_of_points': 18, 'roi_index': 53, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9428a020>, 'num_of_points': 1, 'roi_index': 54, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94288ef0>, 'num_of_points': 11, 'roi_index': 55, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941f05e0>, 'num_of_points': 7, 'roi_index': 56, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941d58f0>, 'num_of_points': 111, 'roi_index': 57, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9425b7e0>, 'num_of_points': 128, 'roi_index': 58, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c942aa390>, 'num_of_points': 18, 'roi_index': 59, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942a8f90>, 'num_of_points': 1, 'roi_index': 60, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942a84f0>, 'num_of_points': 1, 'roi_index': 61, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c7ab0>, 'num_of_points': 1, 'roi_index': 62, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c7060>, 'num_of_points': 1, 'roi_index': 63, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941c59e0>, 'num_of_points': 21, 'roi_index': 64, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9420bc90>, 'num_of_points': 11, 'roi_index': 65, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9420a160>, 'num_of_points': 18, 'roi_index': 66, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94208630>, 'num_of_points': 11, 'roi_index': 67, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941d9300>, 'num_of_points': 14, 'roi_index': 68, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941da520>, 'num_of_points': 1, 'roi_index': 69, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c941dbf10>, 'num_of_points': 26, 'roi_index': 70, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c93fc6750>, 'num_of_points': 1, 'roi_index': 71, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c93fc5e40>, 'num_of_points': 1, 'roi_index': 72, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c93fc4310>, 'num_of_points': 27, 'roi_index': 73, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c93fc2430>, 'num_of_points': 20, 'roi_index': 74, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c93fc3a10>, 'num_of_points': 1, 'roi_index': 75, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9406c7c0>, 'num_of_points': 6, 'roi_index': 76, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9406dad0>, 'num_of_points': 10, 'roi_index': 77, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c93fe82c0>, 'num_of_points': 39, 'roi_index': 78, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c93fea930>, 'num_of_points': 8, 'roi_index': 79, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c93febc40>, 'num_of_points': 8, 'roi_index': 80, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94010f90>, 'num_of_points': 8, 'roi_index': 81, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c940122a0>, 'num_of_points': 8, 'roi_index': 82, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c940138d0>, 'num_of_points': 13, 'roi_index': 83, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c93fed120>, 'num_of_points': 11, 'roi_index': 84, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c93fee750>, 'num_of_points': 10, 'roi_index': 85, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c93ffad40>, 'num_of_points': 87, 'roi_index': 86, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94003e70>, 'num_of_points': 28, 'roi_index': 87, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9400aac0>, 'num_of_points': 28, 'roi_index': 88, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94014d10>, 'num_of_points': 12, 'roi_index': 89, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94016980>, 'num_of_points': 19, 'roi_index': 90, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9401c1d0>, 'num_of_points': 5, 'roi_index': 91, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9401ce50>, 'num_of_points': 1, 'roi_index': 92, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9401dc60>, 'num_of_points': 7, 'roi_index': 93, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9401ea20>, 'num_of_points': 1, 'roi_index': 94, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9401fdd0>, 'num_of_points': 16, 'roi_index': 95, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94029170>, 'num_of_points': 1, 'roi_index': 96, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94030e00>, 'num_of_points': 81, 'roi_index': 97, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9403ac50>, 'num_of_points': 55, 'roi_index': 98, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9404afc0>, 'num_of_points': 38, 'roi_index': 99, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94052070>, 'num_of_points': 25, 'roi_index': 100, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9405b060>, 'num_of_points': 88, 'roi_index': 101, 'roi_type': 'Calcification'}
# Data saved for 53582683 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/53582683
# No split info found for 53582710
# No split info found for 53582737
# No split info found for 53582764
# No split info found for 53582791
# No split info found for 53582818
# No split info found for 53586361
# No split info found for 53586388
# No split info found for 53586415
# No split info found for 53586442
# No split info found for 53586724
# No split info found for 53586751
# No split info found for 53586778
# No split info found for 53586805
# {'points': <Element 'array' at 0x7f9c9435a480>, 'num_of_points': 70, 'roi_index': 0, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c9445cfe0>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9d3a370ae0>, 'num_of_points': 5, 'roi_index': 2, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433f6a0>, 'num_of_points': 5, 'roi_index': 3, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433e7f0>, 'num_of_points': 4, 'roi_index': 4, 'roi_type': 'Calcification'}
# Data saved for 53586869 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/53586869
# {'points': <Element 'array' at 0x7f9c9445c040>, 'num_of_points': 1, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c944d60c0>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94358220>, 'num_of_points': 51, 'roi_index': 2, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c9435ade0>, 'num_of_points': 1, 'roi_index': 3, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943598f0>, 'num_of_points': 1, 'roi_index': 4, 'roi_type': 'Calcification'}
# Data saved for 53586896 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/53586896
# {'points': <Element 'array' at 0x7f9c94ca0810>, 'num_of_points': 1, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c944d6ca0>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94bd9080>, 'num_of_points': 13, 'roi_index': 2, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433d710>, 'num_of_points': 171, 'roi_index': 3, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c942e24d0>, 'num_of_points': 200, 'roi_index': 4, 'roi_type': 'Spiculated Region'}
# {'points': <Element 'array' at 0x7f9c94c75d50>, 'num_of_points': 1, 'roi_index': 5, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94c77f60>, 'num_of_points': 1, 'roi_index': 6, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94c77510>, 'num_of_points': 1, 'roi_index': 7, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94c30a90>, 'num_of_points': 1, 'roi_index': 8, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94c326b0>, 'num_of_points': 1, 'roi_index': 9, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94c33d80>, 'num_of_points': 1, 'roi_index': 10, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9d3a337010>, 'num_of_points': 1, 'roi_index': 11, 'roi_type': 'Calcification'}
# Data saved for 53586960 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/53586960
# No split info found for 53586987
# {'points': <Element 'array' at 0x7f9c94c32070>, 'num_of_points': 19, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942e3ec0>, 'num_of_points': 236, 'roi_index': 1, 'roi_type': 'Mass'}
# {'points': <Element 'array' at 0x7f9c94359080>, 'num_of_points': 200, 'roi_index': 2, 'roi_type': 'Spiculated Region'}
# {'points': <Element 'array' at 0x7f9c94c571a0>, 'num_of_points': 1, 'roi_index': 3, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943713a0>, 'num_of_points': 21, 'roi_index': 4, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94372a20>, 'num_of_points': 1, 'roi_index': 5, 'roi_type': 'Calcification'}
# Data saved for 53587014 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/53587014
# No split info found for 53587041
# No split info found for 53587104
# No split info found for 53587131
# No split info found for 53587427
# No split info found for 53587454
# No split info found for 53587481
# No split info found for 53587508
# No split info found for 53587572
# No split info found for 53587599
# {'points': <Element 'array' at 0x7f9c94ca0860>, 'num_of_points': 1, 'roi_index': 0, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c94ca1120>, 'num_of_points': 1, 'roi_index': 1, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c944d6bb0>, 'num_of_points': 7, 'roi_index': 2, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9d3a370f40>, 'num_of_points': 5, 'roi_index': 3, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9445d170>, 'num_of_points': 5, 'roi_index': 4, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943591c0>, 'num_of_points': 13, 'roi_index': 5, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9435bbf0>, 'num_of_points': 14, 'roi_index': 6, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c9433dd00>, 'num_of_points': 81, 'roi_index': 7, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943117b0>, 'num_of_points': 18, 'roi_index': 8, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c943127a0>, 'num_of_points': 42, 'roi_index': 9, 'roi_type': 'Calcification'}
# {'points': <Element 'array' at 0x7f9c942e19e0>, 'num_of_points': 87, 'roi_index': 10, 'roi_type': 'Mass'}
# out of bound: /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/AllXML/53587663.xml
# {'points': <Element 'array' at 0x7f9c942edda0>, 'num_of_points': 74, 'roi_index': 11, 'roi_type': 'Calcification'}
# Data saved for 53587663 in /home/jovyan/thesis_project/datasets/INbreast/INbreast Release 1.0/VersaMammo_format/Train/53587663
# No split info found for 53587690
# No split info found for 53587717
# No split info found for 53587744
# Dataset processing completed. Total processed: 107

# %% [markdown]
# Classification

# %%
import os
import pandas as pd
import numpy as np
import pydicom as pdcm
import cv2

def np_CountUpContinuingOnes(b_arr):
    left = np.arange(len(b_arr))
    left[b_arr > 0] = 0
    left = np.maximum.accumulate(left)
    rev_arr = b_arr[::-1]
    right = np.arange(len(rev_arr))
    right[rev_arr > 0] = 0
    right = np.maximum.accumulate(right)
    right = len(rev_arr) - 1 - right[::-1]
    return right - left - 1

def ExtractBreast(img):
    img_copy = img.copy()
    img = np.where(img <= 20, 0, img)
    height, _ = img.shape
    y_a = height // 2 + int(height * 0.4)
    y_b = height // 2 - int(height * 0.4)
    b_arr = img[y_b:y_a].std(axis=0) != 0
    continuing_ones = np_CountUpContinuingOnes(b_arr)
    col_ind = np.where(continuing_ones == continuing_ones.max())[0]
    img = img[:, col_ind]
    _, width = img.shape
    x_a = width // 2 + int(width * 0.4)
    x_b = width // 2 - int(width * 0.4)
    b_arr = img[:, x_b:x_a].std(axis=1) != 0
    continuing_ones = np_CountUpContinuingOnes(b_arr)
    row_ind = np.where(continuing_ones == continuing_ones.max())[0]
    return img_copy[row_ind][:, col_ind]

# 读取数据划分CSV文件
split_csv_path = "../classification_data/classification_split.csv"
split_df = pd.read_csv(split_csv_path)
# 只保留INbreast数据集
split_df = split_df[split_df['dataset'] == 'INbreast']

# 读取XLS文件
xls_path = '/Volumes/图图/INBreast/INbreast/INbreast.xls'
df = pd.read_excel(xls_path)

# 合并数据划分信息
df = pd.merge(df, split_df[['data_name', 'data_split']], 
             left_on=df['File Name'].apply(lambda x: str(x).split('.')[0]), 
             right_on='data_name', how='inner')

# 定义输入和输出路径
DCM_PATH = "/Volumes/图图/INBreast/INbreast/AllDICOMs"
OUTPUT_BASE_PATH = "../classification_data/INbreast"

def process_and_save():
    for index, row in df.iterrows():
        file_name = str(row['File Name']).split('.')[0]
        data_split = row['data_split']
        
        # 处理元数据
        meta_data = {
            'Composition': str(row['ACR']).replace(' ',''),
            'Bi-Rads': str(row['Bi-Rads']).replace(' ','')
        }
        
        # 处理Composition
        if meta_data['Composition'] not in ['1', '2', '3', '4']:
            del meta_data['Composition']
        elif 'Composition' in meta_data:
            acr_map = {'1': 'A', '2': 'B', '3': 'C', '4': 'D'}
            meta_data['Composition'] = 'Level ' + acr_map.get(meta_data['Composition'], meta_data['Composition'])
        
        # 处理Bi-Rads
        if 'Bi-Rads' in meta_data:
            if meta_data['Bi-Rads'] in ['4a', '4b', '4c']:
                meta_data['Bi-Rads'] = 'Bi-Rads 4'
            elif meta_data['Bi-Rads'] == '6':
                del meta_data['Bi-Rads']
            elif meta_data['Bi-Rads'] in ['1', '2', '3', '5']:
                meta_data['Bi-Rads'] = f"Bi-Rads {meta_data['Bi-Rads']}"
        
        # 处理异常发现
        abnormality_list = []
        if str(row['Mass']).strip() == 'X':
            abnormality_list.append('Mass')
        if str(row['Micros']).strip() == 'X':
            abnormality_list.append('Calcification')
        if str(row['Distortion']).strip() == 'X':
            abnormality_list.append('Architectural distortion')
        if str(row['Asymmetry']).strip() == 'X':
            abnormality_list.append('Asymmetry')
        if not abnormality_list:
            abnormality_list.append('Normal')
        
        if abnormality_list:
            meta_data['Finding'] = abnormality_list

        # 读取和处理DICOM文件
        dcm_path = os.path.join(DCM_PATH, file_name + '.dcm')
        if os.path.exists(dcm_path):
            dcm = pdcm.dcmread(dcm_path)
            img = dcm.pixel_array
            img = ExtractBreast(img)
            img = cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

            # 保存图像和元数据
            img_output_path = os.path.join(OUTPUT_BASE_PATH, data_split, file_name)
            os.makedirs(img_output_path, exist_ok=True)
            
            jpg_path = os.path.join(img_output_path, 'img.jpg')
            cv2.imwrite(jpg_path, img)
            
            npy_path = os.path.join(img_output_path, 'info_dict.npy')
            np.save(npy_path, meta_data)
            
            print(f"Processed {file_name} for {data_split} set")
        else:
            print(f"DICOM file for {file_name} not found.")

# 处理并保存数据
process_and_save()
print("Processing complete.")
# Out:
# Processed 22580732 for Train set
# Processed 51048972 for Train set
# Processed 50998059 for Train set
# Processed 24055382 for Train set
# Processed 22580706 for Train set
# Processed 50997624 for Train set
# Processed 22670094 for Train set
# Processed 24065461 for Train set
# Processed 50995762 for Train set
# Processed 24055355 for Train set
# Processed 50998177 for Train set
# Processed 50994354 for Train set
# Processed 24065407 for Train set
# Processed 22678833 for Train set
# Processed 53580804 for Train set
# Processed 24065584 for Train set
# Processed 50995899 for Train set
# Processed 50997796 for Train set
# Processed 50998634 for Train set
# Processed 53581796 for Train set
# Processed 30011850 for Train set
# Processed 50996709 for Train set
# Processed 53587663 for Train set
# Processed 50994841 for Train set
# Processed 53581237 for Train set
# Processed 22427751 for Train set
# Processed 50996854 for Train set
# Processed 50999094 for Train set
# Processed 50994327 for Train set
# Processed 50999432 for Train set
# Processed 53587014 for Train set
# Processed 22613970 for Train set
# Processed 22670442 for Train set
# Processed 50993949 for Train set
# Processed 24065557 for Train set
# Processed 50996110 for Train set
# DICOM file for nan not found.
# Processed 22580520 for Train set
# Processed 24065380 for Train set
# Processed 53582791 for Train set
# Processed 50993616 for Train set
# Processed 53582395 for Train set
# Processed 50997823 for Train set
# Processed 50994562 for Train set
# Processed 30011530 for Train set
# Processed 53580885 for Train set
# Processed 20588216 for Train set
# Processed 27829215 for Train set
# Processed 50994895 for Train set
# Processed 24065289 for Train set
# Processed 50994408 for Train set
# Processed 50994535 for Train set
# Processed 22613944 for Train set
# Processed 22580419 for Train set
# Processed 50994868 for Train set
# Processed 22613796 for Train set
# Processed 24055203 for Train set
# Processed 30011700 for Train set
# Processed 22670855 for Train set
# Processed 30011674 for Train set
# Processed 27829188 for Train set
# Processed 24065308 for Train set
# Processed 53586724 for Train set
# Processed 22614379 for Train set
# Processed 53581914 for Train set
# Processed 24055654 for Train set
# Processed 22580393 for Train set
# Processed 20588458 for Train set
# Processed 20588308 for Train set
# Processed 20588562 for Train set
# Processed 50997107 for Train set
# Processed 20586986 for Train set
# Processed 22678670 for Train set
# Processed 22670147 for Train set
# Processed 51049080 for Train set
# Processed 50993643 for Train set
# Processed 51048765 for Train set
# Processed 20588138 for Train set
# Processed 20587758 for Train set
# Processed 22579870 for Train set
# Processed 50998981 for Train set
# Processed 50997488 for Train set
# Processed 53582331 for Train set
# Processed 50999121 for Train set
# Processed 53581941 for Train set
# Processed 50994164 for Train set
# Processed 50996201 for Train set
# Processed 20588510 for Train set
# Processed 22613676 for Train set
# Processed 53582422 for Train set
# Processed 50999300 for Train set
# Processed 22678810 for Train set
# Processed 24055877 for Train set
# Processed 50995789 for Train set
# Processed 50993697 for Train set
# Processed 50993814 for Train set
# Processed 53587717 for Train set
# Processed 20587810 for Train set
# Processed 53580979 for Train set
# Processed 20587466 for Train set
# Processed 51049543 for Train set
# Processed 22614545 for Train set
# Processed 22678495 for Train set
# Processed 50996352 for Train set
# Processed 50994137 for Train set
# Processed 53582737 for Train set
# Processed 53586415 for Train set
# Processed 50998413 for Train set
# Processed 53581264 for Train set
# Processed 22614150 for Train set
# Processed 22427840 for Train set
# Processed 22580576 for Train set
# Processed 24065270 for Train set
# Processed 53586388 for Train set
# Processed 50998661 for Train set
# Processed 22670511 for Train set
# Processed 51049276 for Train set
# Processed 20587372 for Train set
# Processed 24055051 for Train set
# Processed 51048918 for Train set
# Processed 22614074 for Train set
# Processed 30011647 for Train set
# Processed 50995963 for Train set
# Processed 22580098 for Train set
# Processed 22671003 for Train set
# Processed 50994616 for Train set
# Processed 51049489 for Train set
# Processed 20587346 for Train set
# Processed 50994706 for Train set
# Processed 22678472 for Train set
# Processed 22427682 for Train set
# Processed 22614127 for Train set
# Processed 20587902 for Train set
# Processed 53581151 for Train set
# Processed 26933859 for Train set
# Processed 24065734 for Train set
# Processed 53587427 for Train set
# Processed 22678856 for Train set
# Processed 24065887 for Train set
# Processed 53582476 for Train set
# Processed 22670177 for Train set
# Processed 22580341 for Train set
# Processed 24055600 for Train set
# Processed 50997434 for Train set
# Processed 20587994 for Train set
# Processed 24055445 for Train set
# Processed 53586778 for Train set
# Processed 53581887 for Train set
# Processed 53582764 for Train set
# Processed 22580192 for Train set
# Processed 24065611 for Train set
# Processed 50998349 for Train set
# Processed 53586751 for Train set
# Processed 50994733 for Train set
# Processed 20587664 for Train set
# Processed 22670301 for Train set
# Processed 24065761 for Train set
# Processed 22670978 for Train set
# Processed 50996972 for Train set
# Processed 50995990 for Train set
# Processed 20587080 for Train set
# Processed 24054997 for Train set
# Processed 22670278 for Train set
# Processed 50998204 for Train set
# Processed 22427728 for Train set
# Processed 22579730 for Train set
# Processed 50998032 for Train set
# Processed 24058660 for Train set
# Processed 22678787 for Train set
# Processed 22614097 for Train set
# Processed 20588046 for Train set
# Processed 22613848 for Train set
# Processed 50999246 for Train set
# Processed 24065707 for Train set
# Processed 24058738 for Train set
# Processed 30011484 for Train set
# Processed 53587508 for Train set
# Processed 26933772 for Train set
# Processed 20588654 for Train set
# Processed 22579754 for Train set
# Processed 22670465 for Train set
# Processed 51048945 for Train set
# Processed 24065434 for Train set
# Processed 22678449 for Train set
# Processed 24055149 for Train set
# Processed 24055176 for Train set
# Processed 50994300 for Train set
# Processed 51049628 for Train set
# Processed 53586960 for Train set
# Processed 53587572 for Train set
# Processed 24055904 for Train set
# Processed 22613624 for Train set
# Processed 22670643 for Train set
# Processed 20587174 for Train set
# Processed 24055573 for Train set
# Processed 24065530 for Train set
# Processed 50997223 for Train set
# Processed 50996056 for Train set
# Processed 22670878 for Train set
# Processed 50999273 for Train set
# Processed 30318067 for Train set
# Processed 50994191 for Train set
# Processed 53582304 for Train set
# Processed 50997080 for Train set
# Processed 50993399 for Train set
# Processed 50998322 for Train set
# Processed 20587690 for Train set
# Processed 24058686 for Train set
# Processed 20587928 for Train set
# Processed 20586934 for Train set
# Processed 50997026 for Train set
# Processed 22678694 for Train set
# Processed 53580692 for Train set
# Processed 51049516 for Train set
# Processed 24065833 for Train set
# Processed 53587041 for Train set
# Processed 22613822 for Train set
# Processed 22580270 for Train set
# Processed 22580548 for Train set
# Processed 53581433 for Train set
# Processed 50997053 for Train set
# Processed 53582656 for Train set
# Processed 22670124 for Train set
# Processed 51049134 for Train set
# Processed 50996999 for Train set
# Processed 50996736 for Train set
# Processed 22613770 for Train set
# Processed 50997304 for Train set
# Processed 50994814 for Train set
# Processed 53582683 for Train set
# Processed 30011798 for Train set
# Processed 22678518 for Train set
# Processed 53586987 for Train set
# Processed 24065680 for Train set
# Processed 22613702 for Train set
# Processed 50998113 for Train set
# Processed 50998494 for Train set
# Processed 53587454 for Train set
# Processed 20588020 for Train set
# Processed 30011727 for Train set
# Processed 53586896 for Train set
# Processed 53587104 for Train set
# Processed 51049655 for Train set
# Processed 20587492 for Train set
# Processed 22614568 for Train set
# Processed 22678646 for Train set
# Processed 20586960 for Train set
# Processed 22580015 for Train set
# Processed 50997597 for Train set
# Processed 24055078 for Train set
# Processed 50996083 for Train set
# Processed 22613650 for Train set
# Processed 50997515 for Train set
# Processed 50994110 for Train set
# Processed 24058712 for Train set
# Processed 50999148 for Train set
# Processed 20587836 for Train set
# Processed 53586869 for Train set
# Processed 20588072 for Train set
# Processed 24065251 for Train set
# Processed 53581460 for Train set
# Processed 53582818 for Train set
# Processed 50997250 for Train set
# Processed 50996827 for Train set
# Processed 51048891 for Train set
# Processed 50994273 for Train set
# Processed 53580858 for Train set
# Processed 27829161 for Train set
# Processed 24055464 for Train set
# Processed 22580654 for Train set
# Processed 24055806 for Train set
# Processed 24055958 for Train set
# Processed 24055024 for Train set
# Processed 51049107 for Train set
# Processed 53581006 for Train set
# Processed 50994760 for Train set
# Processed 50993841 for Train set
# Processed 50997134 for Train set
# Processed 50993895 for Train set
# Processed 20587054 for Train set
# Processed 22614353 for Train set
# Processed 22614405 for Train set
# Processed 22670620 for Train set
# Processed 50996881 for Train set
# Processed 24065860 for Train set
# Processed 20587544 for Train set
# Processed 50993868 for Train set
# Processed 22580244 for Eval set
# Processed 50997277 for Eval set
# Processed 22670324 for Eval set
# Processed 50995872 for Eval set
# Processed 50999459 for Eval set
# Processed 53581060 for Eval set
# Processed 20587638 for Eval set
# Processed 50994589 for Eval set
# Processed 50993922 for Eval set
# Processed 53581379 for Eval set
# Processed 53587599 for Eval set
# Processed 20586908 for Eval set
# Processed 24055328 for Eval set
# Processed 50998231 for Eval set
# Processed 20587200 for Eval set
# Processed 50999175 for Eval set
# Processed 50996945 for Eval set
# Processed 53586805 for Eval set
# Processed 50998440 for Eval set
# Processed 53587131 for Eval set
# Processed 50994381 for Eval set
# Processed 22580680 for Eval set
# Processed 30011824 for Eval set
# Processed 24055274 for Eval set
# Processed 50993976 for Eval set
# Processed 53582567 for Eval set
# Processed 51049682 for Eval set
# Processed 22580367 for Eval set
# Processed 22579847 for Eval set
# Processed 24055483 for Eval set
# Processed 22614431 for Eval set
# Processed 53580665 for Eval set
# Processed 50996137 for Eval set
# Processed 30011507 for Eval set
# Processed 50999008 for Eval set
# Processed 22614236 for Eval set
# Processed 20587320 for Eval set
# Processed 20588164 for Eval set
# Processed 22670488 for Eval set
# Processed 22579893 for Eval set
# Processed 51049249 for Eval set
# Processed 51049462 for Eval set
# Processed 22614522 for Test set
# Processed 51070197 for Test set
# Processed 50999327 for Test set
# Processed 53581406 for Test set
# Processed 53580831 for Test set
# Processed 20588680 for Test set
# Processed 22614266 for Test set
# Processed 50996800 for Test set
# Processed 51049053 for Test set
# Processed 53581860 for Test set
# Processed 22670673 for Test set
# Processed 50994787 for Test set
# Processed 50997651 for Test set
# Processed 50998467 for Test set
# Processed 22670832 for Test set
# Processed 53580611 for Test set
# Processed 20587148 for Test set
# Processed 20587612 for Test set
# Processed 22580492 for Test set
# Processed 22679036 for Test set
# Processed 53581124 for Test set
# Processed 50997461 for Test set
# DICOM file for nan not found.
# Processed 20588536 for Test set
# Processed 20587784 for Test set
# Processed 50993426 for Test set
# Processed 50997678 for Test set
# Processed 50996406 for Test set
# Processed 50998607 for Test set
# Processed 22427705 for Test set
# Processed 24055752 for Test set
# Processed 22670347 for Test set
# Processed 22679008 for Test set
# Processed 50993670 for Test set
# Processed 22613996 for Test set
# Processed 22579916 for Test set
# Processed 20587226 for Test set
# Processed 53581769 for Test set
# Processed 24055502 for Test set
# Processed 50996379 for Test set
# Processed 22678622 for Test set
# Processed 53582540 for Test set
# Processed 53587690 for Test set
# Processed 22427864 for Test set
# Processed 53587744 for Test set
# Processed 50996325 for Test set
# Processed 22670809 for Test set
# Processed 20587518 for Test set
# Processed 27829134 for Test set
# Processed 50993787 for Test set
# Processed 22614499 for Test set
# Processed 22580038 for Test set
# Processed 50996228 for Test set
# Processed 24055931 for Test set
# Processed 26933830 for Test set
# Processed 24055627 for Test set
# Processed 24065914 for Test set
# Processed 22580068 for Test set
# Processed 50997769 for Test set
# Processed 20588334 for Test set
# Processed 53586361 for Test set
# Processed 30011553 for Test set
# Processed 22678980 for Test set
# Processed 53582449 for Test set
# Processed 50998086 for Test set
# Processed 53587481 for Test set
# Processed 22678953 for Test set
# Processed 53582710 for Test set
# Processed 20588190 for Test set
# Processed 51048738 for Test set
# Processed 53580638 for Test set
# Processed 24055779 for Test set
# Processed 50997742 for Test set
# Processed 22580218 for Test set
# Processed 53581033 for Test set
# Processed 50998580 for Test set
# Processed 22670703 for Test set
# Processed 22613918 for Test set
# Processed 50998258 for Test set
# Processed 53586442 for Test set
# Processed 20587294 for Test set
# Processed 24055725 for Test set
# Processed 26933801 for Test set
